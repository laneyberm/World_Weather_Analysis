# %%
# Import the dependencies.
import pandas as pd
import gmaps
import numpy as np
import requests
import time
from datetime import datetime
from citipy import citipy
import random

# Import the API key.
from config import g_key
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Pack the latitudes (lats) and longitudes (lngs) as pairs by zipping them.
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities and get hte nearest city using the citypy module.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 772

# %%
# Create an empty list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
set_count = 1

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | majene
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | bolobo
# Processing Record 7 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 1 | sitka
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | kruisfontein
# Processing Record 15 of Set 1 | college
# Processing Record 16 of Set 1 | gayeri
# Processing Record 17 of Set 1 | pishchanka
# City not found. Skipping...
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | kidal
# Processing Record 20 of Set 1 | slupca
# Processing Record 21 of Set 1 | potiskum
# Processing Record 22 of Set 1 | kodiak
# Processing Record 23 of Set 1 | morant bay
# Processing Record 24 of Set 1 | katherine
# Processing Record 25 of Set 1 | providencia
# Processing Record 26 of Set 1 | sao filipe
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | ayan
# Processing Record 29 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 1 | kaniama
# Processing Record 31 of Set 1 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 32 of Set 1 | lebu
# Processing Record 33 of Set 1 | garowe
# Processing Record 34 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 1 | la asuncion
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | agnibilekrou
# Processing Record 38 of Set 1 | namibe
# Processing Record 39 of Set 1 | tiznit
# Processing Record 40 of Set 1 | alice springs
# Processing Record 41 of Set 1 | cuzdrioara
# Processing Record 42 of Set 1 | severo-kurilsk
# Processing Record 43 of Set 1 | san patricio
# Processing Record 44 of Set 1 | aksarka
# Processing Record 45 of Set 1 | sao joao da barra
# Processing Record 46 of Set 1 | ahipara
# Processing Record 47 of Set 1 | kiunga
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | gazanjyk
# Processing Record 50 of Set 1 | kalyazin
# Processing Record 1 of Set 2 | saint george
# Processing Record 2 of Set 2 | artyom
# Processing Record 3 of Set 2 | kaitangata
# Processing Record 4 of Set 2 | hualmay
# Processing Record 5 of Set 2 | rocha
# Processing Record 6 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 2 | heilbron
# Processing Record 8 of Set 2 | ribeira grande
# Processing Record 9 of Set 2 | payson
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | rzhev
# Processing Record 12 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 2 | rotifunk
# Processing Record 14 of Set 2 | riviera beach
# Processing Record 15 of Set 2 | axim
# Processing Record 16 of Set 2 | souillac
# Processing Record 17 of Set 2 | goderich
# Processing Record 18 of Set 2 | mahebourg
# Processing Record 19 of Set 2 | khatanga
# Processing Record 20 of Set 2 | labuhan
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | george
# Processing Record 23 of Set 2 | barra patuca
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | victoria
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | teya
# Processing Record 28 of Set 2 | limon
# Processing Record 29 of Set 2 | pevek
# Processing Record 30 of Set 2 | te anau
# Processing Record 31 of Set 2 | samarai
# Processing Record 32 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 2 | rikitea
# Processing Record 34 of Set 2 | upernavik
# Processing Record 35 of Set 2 | carnarvon
# Processing Record 36 of Set 2 | maragogi
# Processing Record 37 of Set 2 | nikolskoye
# Processing Record 38 of Set 2 | shubarkuduk
# Processing Record 39 of Set 2 | maneromango
# Processing Record 40 of Set 2 | wilmington
# Processing Record 41 of Set 2 | barrow
# Processing Record 42 of Set 2 | laguna
# Processing Record 43 of Set 2 | bethel
# Processing Record 44 of Set 2 | lagos
# Processing Record 45 of Set 2 | chokurdakh
# Processing Record 46 of Set 2 | qostanay
# Processing Record 47 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 2 | hermanus
# Processing Record 49 of Set 2 | muros
# Processing Record 50 of Set 2 | muzhi
# Processing Record 1 of Set 3 | prince rupert
# Processing Record 2 of Set 3 | oranjemund
# Processing Record 3 of Set 3 | marhaura
# Processing Record 4 of Set 3 | haimen
# Processing Record 5 of Set 3 | dikson
# Processing Record 6 of Set 3 | hilo
# Processing Record 7 of Set 3 | champerico
# Processing Record 8 of Set 3 | ponta do sol
# Processing Record 9 of Set 3 | chuy
# Processing Record 10 of Set 3 | vilhena
# Processing Record 11 of Set 3 | sai buri
# Processing Record 12 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 3 | hobart
# Processing Record 14 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 3 | lagoa
# Processing Record 16 of Set 3 | vostok
# Processing Record 17 of Set 3 | xiaoweizhai
# Processing Record 18 of Set 3 | port-gentil
# Processing Record 19 of Set 3 | ozinki
# Processing Record 20 of Set 3 | myitkyina
# Processing Record 21 of Set 3 | punta arenas
# Processing Record 22 of Set 3 | armidale
# Processing Record 23 of Set 3 | zapolyarnyy
# Processing Record 24 of Set 3 | leningradskiy
# Processing Record 25 of Set 3 | saint-philippe
# Processing Record 26 of Set 3 | birin
# Processing Record 27 of Set 3 | nuevo progreso
# Processing Record 28 of Set 3 | vila velha
# Processing Record 29 of Set 3 | sinnamary
# Processing Record 30 of Set 3 | makinsk
# Processing Record 31 of Set 3 | presidencia roque saenz pena
# Processing Record 32 of Set 3 | butaritari
# Processing Record 33 of Set 3 | asau
# Processing Record 34 of Set 3 | albany
# Processing Record 35 of Set 3 | high rock
# Processing Record 36 of Set 3 | san cristobal
# Processing Record 37 of Set 3 | tselinnoye
# Processing Record 38 of Set 3 | tuktoyaktuk
# Processing Record 39 of Set 3 | coahuayana
# Processing Record 40 of Set 3 | chicama
# Processing Record 41 of Set 3 | klaksvik
# Processing Record 42 of Set 3 | terekli-mekteb
# Processing Record 43 of Set 3 | east london
# Processing Record 44 of Set 3 | gornyatskiy
# Processing Record 45 of Set 3 | adrar
# Processing Record 46 of Set 3 | guanica
# Processing Record 47 of Set 3 | wabash
# Processing Record 48 of Set 3 | sisimiut
# Processing Record 49 of Set 3 | cap malheureux
# Processing Record 50 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 4 | pisco
# Processing Record 2 of Set 4 | kormilovka
# Processing Record 3 of Set 4 | antalaha
# Processing Record 4 of Set 4 | teahupoo
# Processing Record 5 of Set 4 | castro
# Processing Record 6 of Set 4 | christchurch
# Processing Record 7 of Set 4 | nizwa
# Processing Record 8 of Set 4 | luau
# Processing Record 9 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 4 | wajir
# Processing Record 11 of Set 4 | lazaro cardenas
# Processing Record 12 of Set 4 | sorong
# Processing Record 13 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 4 | shakiso
# Processing Record 16 of Set 4 | porto walter
# Processing Record 17 of Set 4 | port lincoln
# Processing Record 18 of Set 4 | bambous virieux
# Processing Record 19 of Set 4 | la ronge
# Processing Record 20 of Set 4 | zhigalovo
# Processing Record 21 of Set 4 | longyearbyen
# Processing Record 22 of Set 4 | acarau
# Processing Record 23 of Set 4 | yerbogachen
# Processing Record 24 of Set 4 | clive
# Processing Record 25 of Set 4 | saint-pierre
# Processing Record 26 of Set 4 | gat
# Processing Record 27 of Set 4 | wattegama
# Processing Record 28 of Set 4 | new albany
# Processing Record 29 of Set 4 | lithgow
# Processing Record 30 of Set 4 | podor
# Processing Record 31 of Set 4 | skjervoy
# Processing Record 32 of Set 4 | provideniya
# Processing Record 33 of Set 4 | billings
# Processing Record 34 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 4 | amahai
# Processing Record 36 of Set 4 | northam
# Processing Record 37 of Set 4 | kismayo
# Processing Record 38 of Set 4 | neftcala
# Processing Record 39 of Set 4 | moose factory
# Processing Record 40 of Set 4 | aloleng
# Processing Record 41 of Set 4 | vardo
# Processing Record 42 of Set 4 | saint anthony
# Processing Record 43 of Set 4 | maine-soroa
# Processing Record 44 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 45 of Set 4 | bredasdorp
# Processing Record 46 of Set 4 | pacifica
# Processing Record 47 of Set 4 | natal
# Processing Record 48 of Set 4 | lavrentiya
# Processing Record 49 of Set 4 | capao da canoa
# Processing Record 50 of Set 4 | kazanskoye
# Processing Record 1 of Set 5 | tabasco
# Processing Record 2 of Set 5 | taoudenni
# Processing Record 3 of Set 5 | katsuura
# Processing Record 4 of Set 5 | anadyr
# Processing Record 5 of Set 5 | fortuna
# Processing Record 6 of Set 5 | mildura
# Processing Record 7 of Set 5 | bilma
# Processing Record 8 of Set 5 | popova
# Processing Record 9 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 10 of Set 5 | manggar
# Processing Record 11 of Set 5 | nohar
# Processing Record 12 of Set 5 | qaanaaq
# Processing Record 13 of Set 5 | abnub
# Processing Record 14 of Set 5 | elk point
# Processing Record 15 of Set 5 | tiksi
# Processing Record 16 of Set 5 | iquique
# Processing Record 17 of Set 5 | bathsheba
# Processing Record 18 of Set 5 | aswan
# Processing Record 19 of Set 5 | maxixe
# Processing Record 20 of Set 5 | vestmannaeyjar
# Processing Record 21 of Set 5 | margate
# Processing Record 22 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 5 | saint-augustin
# Processing Record 24 of Set 5 | srivardhan
# Processing Record 25 of Set 5 | sosnovo-ozerskoye
# Processing Record 26 of Set 5 | touros
# Processing Record 27 of Set 5 | aktash
# Processing Record 28 of Set 5 | hoi an
# Processing Record 29 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 5 | vaini
# Processing Record 31 of Set 5 | kemijarvi
# Processing Record 32 of Set 5 | mattru
# Processing Record 33 of Set 5 | shahada
# Processing Record 34 of Set 5 | hambantota
# Processing Record 35 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 5 | honningsvag
# Processing Record 37 of Set 5 | tasiilaq
# Processing Record 38 of Set 5 | tuatapere
# Processing Record 39 of Set 5 | mandal
# Processing Record 40 of Set 5 | port shepstone
# Processing Record 41 of Set 5 | seymour
# Processing Record 42 of Set 5 | ostrovnoy
# Processing Record 43 of Set 5 | kaeo
# Processing Record 44 of Set 5 | iqaluit
# Processing Record 45 of Set 5 | puerto ayora
# Processing Record 46 of Set 5 | cabo san lucas
# Processing Record 47 of Set 5 | boo
# Processing Record 48 of Set 5 | narsaq
# Processing Record 49 of Set 5 | dingle
# Processing Record 50 of Set 5 | cirebon
# Processing Record 1 of Set 6 | byron bay
# Processing Record 2 of Set 6 | thompson
# Processing Record 3 of Set 6 | ilulissat
# Processing Record 4 of Set 6 | mangochi
# Processing Record 5 of Set 6 | vila franca do campo
# Processing Record 6 of Set 6 | maralal
# Processing Record 7 of Set 6 | kurilsk
# Processing Record 8 of Set 6 | bandar-e lengeh
# Processing Record 9 of Set 6 | ambulu
# Processing Record 10 of Set 6 | santa isabel do rio negro
# Processing Record 11 of Set 6 | leh
# Processing Record 12 of Set 6 | bayan
# Processing Record 13 of Set 6 | salalah
# Processing Record 14 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 6 | norman wells
# Processing Record 16 of Set 6 | we
# City not found. Skipping...
# Processing Record 17 of Set 6 | lucapa
# Processing Record 18 of Set 6 | kletnya
# Processing Record 19 of Set 6 | alofi
# Processing Record 20 of Set 6 | garden city
# Processing Record 21 of Set 6 | makat
# Processing Record 22 of Set 6 | verkhoyansk
# Processing Record 23 of Set 6 | hamilton
# Processing Record 24 of Set 6 | jiuquan
# Processing Record 25 of Set 6 | esmeraldas
# Processing Record 26 of Set 6 | hope
# Processing Record 27 of Set 6 | mar del plata
# Processing Record 28 of Set 6 | nordborg
# Processing Record 29 of Set 6 | conakry
# Processing Record 30 of Set 6 | kindu
# Processing Record 31 of Set 6 | churintzio
# Processing Record 32 of Set 6 | higuey
# City not found. Skipping...
# Processing Record 33 of Set 6 | arraial do cabo
# Processing Record 34 of Set 6 | shipunovo
# Processing Record 35 of Set 6 | takoradi
# Processing Record 36 of Set 6 | hjelset
# Processing Record 37 of Set 6 | gambela
# Processing Record 38 of Set 6 | tigil
# Processing Record 39 of Set 6 | vanimo
# Processing Record 40 of Set 6 | filingue
# Processing Record 41 of Set 6 | okha
# Processing Record 42 of Set 6 | usinsk
# Processing Record 43 of Set 6 | airai
# Processing Record 44 of Set 6 | kalmunai
# Processing Record 45 of Set 6 | kaili
# Processing Record 46 of Set 6 | priiskovyy
# Processing Record 47 of Set 6 | zlobin
# Processing Record 48 of Set 6 | cherskiy
# Processing Record 49 of Set 6 | turukhansk
# Processing Record 50 of Set 6 | masyaf
# Processing Record 1 of Set 7 | walvis bay
# Processing Record 2 of Set 7 | haines junction
# Processing Record 3 of Set 7 | sola
# Processing Record 4 of Set 7 | panzhihua
# Processing Record 5 of Set 7 | mezen
# Processing Record 6 of Set 7 | ancud
# Processing Record 7 of Set 7 | bridlington
# Processing Record 8 of Set 7 | tura
# Processing Record 9 of Set 7 | codrington
# Processing Record 10 of Set 7 | irbeyskoye
# Processing Record 11 of Set 7 | phibun mangsahan
# Processing Record 12 of Set 7 | nouadhibou
# Processing Record 13 of Set 7 | port macquarie
# Processing Record 14 of Set 7 | riyadh
# Processing Record 15 of Set 7 | leshukonskoye
# Processing Record 16 of Set 7 | vanavara
# Processing Record 17 of Set 7 | henties bay
# Processing Record 18 of Set 7 | russell
# Processing Record 19 of Set 7 | torbay
# Processing Record 20 of Set 7 | mersing
# Processing Record 21 of Set 7 | bajil
# Processing Record 22 of Set 7 | husavik
# Processing Record 23 of Set 7 | dimapur
# Processing Record 24 of Set 7 | moss vale
# Processing Record 25 of Set 7 | eydhafushi
# Processing Record 26 of Set 7 | liverpool
# Processing Record 27 of Set 7 | jalingo
# Processing Record 28 of Set 7 | tomohon
# Processing Record 29 of Set 7 | mortka
# Processing Record 30 of Set 7 | san quintin
# Processing Record 31 of Set 7 | waipawa
# Processing Record 32 of Set 7 | huilong
# Processing Record 33 of Set 7 | port-cartier
# Processing Record 34 of Set 7 | martapura
# Processing Record 35 of Set 7 | inhambane
# Processing Record 36 of Set 7 | nyurba
# Processing Record 37 of Set 7 | massakory
# Processing Record 38 of Set 7 | port hawkesbury
# Processing Record 39 of Set 7 | kharp
# Processing Record 40 of Set 7 | tashla
# Processing Record 41 of Set 7 | alyangula
# Processing Record 42 of Set 7 | nelson bay
# Processing Record 43 of Set 7 | mucurapo
# Processing Record 44 of Set 7 | truckee
# Processing Record 45 of Set 7 | owensboro
# Processing Record 46 of Set 7 | esna
# Processing Record 47 of Set 7 | la union
# Processing Record 48 of Set 7 | sovetskaya
# Processing Record 49 of Set 7 | mount gambier
# Processing Record 50 of Set 7 | hovd
# Processing Record 1 of Set 8 | glinishchevo
# Processing Record 2 of Set 8 | saint-joseph
# Processing Record 3 of Set 8 | pontal do parana
# Processing Record 4 of Set 8 | pallasovka
# Processing Record 5 of Set 8 | bekovo
# Processing Record 6 of Set 8 | halifax
# Processing Record 7 of Set 8 | jiwani
# Processing Record 8 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 9 of Set 8 | coihaique
# Processing Record 10 of Set 8 | charters towers
# Processing Record 11 of Set 8 | antsohihy
# Processing Record 12 of Set 8 | coquimbo
# Processing Record 13 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 8 | dagda
# Processing Record 15 of Set 8 | pietarsaari
# Processing Record 16 of Set 8 | mamontovo
# Processing Record 17 of Set 8 | micheweni
# Processing Record 18 of Set 8 | sakakah
# Processing Record 19 of Set 8 | yulara
# Processing Record 20 of Set 8 | krasnoselkup
# Processing Record 21 of Set 8 | shenjiamen
# Processing Record 22 of Set 8 | sahrak
# City not found. Skipping...
# Processing Record 23 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 24 of Set 8 | lubsko
# Processing Record 25 of Set 8 | banda aceh
# Processing Record 26 of Set 8 | timra
# Processing Record 27 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 28 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 29 of Set 8 | pravdinsk
# Processing Record 30 of Set 8 | araouane
# Processing Record 31 of Set 8 | sri aman
# Processing Record 32 of Set 8 | sao bernardo
# Processing Record 33 of Set 8 | ahuimanu
# Processing Record 34 of Set 8 | palma
# Processing Record 35 of Set 8 | urumqi
# Processing Record 36 of Set 8 | dickinson
# Processing Record 37 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 8 | matagami
# Processing Record 39 of Set 8 | san luis
# Processing Record 40 of Set 8 | menongue
# Processing Record 41 of Set 8 | pampa
# Processing Record 42 of Set 8 | tessalit
# Processing Record 43 of Set 8 | dotnuva
# Processing Record 44 of Set 8 | gotsu
# Processing Record 45 of Set 8 | rorvik
# Processing Record 46 of Set 8 | sao jose da coroa grande
# Processing Record 47 of Set 8 | ous
# Processing Record 48 of Set 8 | rio grande
# Processing Record 49 of Set 8 | dromolaxia
# Processing Record 50 of Set 8 | zyryanka
# Processing Record 1 of Set 9 | nhulunbuy
# Processing Record 2 of Set 9 | gorontalo
# Processing Record 3 of Set 9 | bereda
# Processing Record 4 of Set 9 | katghora
# Processing Record 5 of Set 9 | nalut
# Processing Record 6 of Set 9 | taltal
# Processing Record 7 of Set 9 | nanortalik
# Processing Record 8 of Set 9 | tucurui
# Processing Record 9 of Set 9 | santa fe
# Processing Record 10 of Set 9 | clonakilty
# Processing Record 11 of Set 9 | nizhniy ingash
# Processing Record 12 of Set 9 | kalat
# Processing Record 13 of Set 9 | berlevag
# Processing Record 14 of Set 9 | balabac
# Processing Record 15 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 16 of Set 9 | herat
# Processing Record 17 of Set 9 | clyde river
# Processing Record 18 of Set 9 | kalengwa
# Processing Record 19 of Set 9 | itaqui
# Processing Record 20 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 9 | faanui
# Processing Record 22 of Set 9 | huarmey
# Processing Record 23 of Set 9 | waingapu
# Processing Record 24 of Set 9 | westport
# Processing Record 25 of Set 9 | hervey bay
# Processing Record 26 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 27 of Set 9 | sembe
# Processing Record 28 of Set 9 | weinan
# Processing Record 29 of Set 9 | podporozhye
# Processing Record 30 of Set 9 | zolochiv
# Processing Record 31 of Set 9 | chignahuapan
# Processing Record 32 of Set 9 | esperance
# Processing Record 33 of Set 9 | bangaon
# Processing Record 34 of Set 9 | remedios
# Processing Record 35 of Set 9 | kuryk
# Processing Record 36 of Set 9 | sur
# Processing Record 37 of Set 9 | phalaborwa
# Processing Record 38 of Set 9 | yeppoon
# Processing Record 39 of Set 9 | bakchar
# Processing Record 40 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 41 of Set 9 | uglich
# Processing Record 42 of Set 9 | bocaue
# Processing Record 43 of Set 9 | arlit
# Processing Record 44 of Set 9 | khani
# Processing Record 45 of Set 9 | zhuhai
# Processing Record 46 of Set 9 | meulaboh
# Processing Record 47 of Set 9 | seguela
# Processing Record 48 of Set 9 | troitskoye
# Processing Record 49 of Set 9 | monte patria
# Processing Record 50 of Set 9 | colares
# Processing Record 1 of Set 10 | atar
# Processing Record 2 of Set 10 | trelew
# Processing Record 3 of Set 10 | maceio
# Processing Record 4 of Set 10 | vestmanna
# Processing Record 5 of Set 10 | smolyaninovo
# Processing Record 6 of Set 10 | boddam
# Processing Record 7 of Set 10 | businga
# Processing Record 8 of Set 10 | beypur
# City not found. Skipping...
# Processing Record 9 of Set 10 | aykhal
# Processing Record 10 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 11 of Set 10 | harper
# Processing Record 12 of Set 10 | woodward
# Processing Record 13 of Set 10 | merauke
# Processing Record 14 of Set 10 | yaransk
# Processing Record 15 of Set 10 | abai
# Processing Record 16 of Set 10 | beyneu
# Processing Record 17 of Set 10 | cooma
# Processing Record 18 of Set 10 | richards bay
# Processing Record 19 of Set 10 | fort walton beach
# Processing Record 20 of Set 10 | liku
# Processing Record 21 of Set 10 | ixtapa
# Processing Record 22 of Set 10 | udachnyy
# Processing Record 23 of Set 10 | el vigia
# Processing Record 24 of Set 10 | mwinilunga
# Processing Record 25 of Set 10 | lubango
# Processing Record 26 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 10 | kavieng
# Processing Record 28 of Set 10 | praxedis guerrero
# Processing Record 29 of Set 10 | warrnambool
# Processing Record 30 of Set 10 | san juan
# Processing Record 31 of Set 10 | bulgan
# Processing Record 32 of Set 10 | guerrero negro
# Processing Record 33 of Set 10 | cairns
# Processing Record 34 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 10 | san andres
# Processing Record 36 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 37 of Set 10 | phan thiet
# Processing Record 38 of Set 10 | pitimbu
# Processing Record 39 of Set 10 | neuquen
# Processing Record 40 of Set 10 | fort nelson
# Processing Record 41 of Set 10 | jackson
# Processing Record 42 of Set 10 | toamasina
# Processing Record 43 of Set 10 | ixcaquixtla
# City not found. Skipping...
# Processing Record 44 of Set 10 | dali
# Processing Record 45 of Set 10 | camaqua
# Processing Record 46 of Set 10 | sarkand
# Processing Record 47 of Set 10 | cayenne
# Processing Record 48 of Set 10 | cockburn town
# Processing Record 49 of Set 10 | ust-nera
# Processing Record 50 of Set 10 | anjar
# Processing Record 1 of Set 11 | hasaki
# Processing Record 2 of Set 11 | cabedelo
# Processing Record 3 of Set 11 | kavaratti
# Processing Record 4 of Set 11 | potam
# Processing Record 5 of Set 11 | nantucket
# Processing Record 6 of Set 11 | poronaysk
# Processing Record 7 of Set 11 | borlange
# City not found. Skipping...
# Processing Record 8 of Set 11 | siruguppa
# Processing Record 9 of Set 11 | seydi
# Processing Record 10 of Set 11 | pacific grove
# Processing Record 11 of Set 11 | umm lajj
# Processing Record 12 of Set 11 | amparafaravola
# Processing Record 13 of Set 11 | kysyl-syr
# Processing Record 14 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 11 | salinopolis
# Processing Record 16 of Set 11 | hay river
# Processing Record 17 of Set 11 | saskylakh
# Processing Record 18 of Set 11 | asuncion
# Processing Record 19 of Set 11 | klyuchi
# Processing Record 20 of Set 11 | yialos
# City not found. Skipping...
# Processing Record 21 of Set 11 | senanga
# Processing Record 22 of Set 11 | hami
# Processing Record 23 of Set 11 | nizhniy baskunchak
# Processing Record 24 of Set 11 | alihe
# Processing Record 25 of Set 11 | key west
# Processing Record 26 of Set 11 | lorengau
# Processing Record 27 of Set 11 | grand gaube
# Processing Record 28 of Set 11 | mount isa
# Processing Record 29 of Set 11 | mongu
# Processing Record 30 of Set 11 | cidreira
# Processing Record 31 of Set 11 | praia da vitoria
# Processing Record 32 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 33 of Set 11 | quatre cocos
# Processing Record 34 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 11 | eureka
# Processing Record 36 of Set 11 | tazovskiy
# Processing Record 37 of Set 11 | sungairaya
# Processing Record 38 of Set 11 | conceicao do araguaia
# Processing Record 39 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 40 of Set 11 | sutton
# Processing Record 41 of Set 11 | ola
# Processing Record 42 of Set 11 | berbera
# Processing Record 43 of Set 11 | evensk
# Processing Record 44 of Set 11 | nome
# Processing Record 45 of Set 11 | san bartolome de tirajana
# Processing Record 46 of Set 11 | bengkulu
# Processing Record 47 of Set 11 | tena
# Processing Record 48 of Set 11 | dangtu
# Processing Record 49 of Set 11 | redlands
# Processing Record 50 of Set 11 | hofn
# Processing Record 1 of Set 12 | angul
# Processing Record 2 of Set 12 | murindo
# Processing Record 3 of Set 12 | kieta
# Processing Record 4 of Set 12 | tondano
# Processing Record 5 of Set 12 | avera
# Processing Record 6 of Set 12 | gibara
# Processing Record 7 of Set 12 | taburbah
# City not found. Skipping...
# Processing Record 8 of Set 12 | berdigestyakh
# Processing Record 9 of Set 12 | tukan
# Processing Record 10 of Set 12 | kamenka
# Processing Record 11 of Set 12 | constitucion
# Processing Record 12 of Set 12 | innisfail
# Processing Record 13 of Set 12 | high level
# Processing Record 14 of Set 12 | athmallik
# Processing Record 15 of Set 12 | marsh harbour
# Processing Record 16 of Set 12 | katakwi
# Processing Record 17 of Set 12 | tongchuan
# Processing Record 18 of Set 12 | narasannapeta
# Processing Record 19 of Set 12 | benghazi
# Processing Record 20 of Set 12 | kashi
# Processing Record 21 of Set 12 | ransang
# Processing Record 22 of Set 12 | mercedes
# Processing Record 23 of Set 12 | bandarbeyla
# Processing Record 24 of Set 12 | dhidhdhoo
# Processing Record 25 of Set 12 | shalinskoye
# Processing Record 26 of Set 12 | moroni
# Processing Record 27 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 28 of Set 12 | prieska
# Processing Record 29 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 30 of Set 12 | kurayoshi
# Processing Record 31 of Set 12 | gamba
# Processing Record 32 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 33 of Set 12 | candolim
# Processing Record 34 of Set 12 | ambon
# Processing Record 35 of Set 12 | saint-georges
# Processing Record 36 of Set 12 | belebey
# Processing Record 37 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 38 of Set 12 | hue
# Processing Record 39 of Set 12 | khash
# Processing Record 40 of Set 12 | tautira
# Processing Record 41 of Set 12 | machado
# Processing Record 42 of Set 12 | peachland
# Processing Record 43 of Set 12 | banmo
# City not found. Skipping...
# Processing Record 44 of Set 12 | birao
# Processing Record 45 of Set 12 | caravelas
# Processing Record 46 of Set 12 | sao joao dos patos
# Processing Record 47 of Set 12 | pangnirtung
# Processing Record 48 of Set 12 | malayal
# Processing Record 49 of Set 12 | baghdad
# Processing Record 50 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 1 of Set 13 | geraldton
# Processing Record 2 of Set 13 | semenyih
# Processing Record 3 of Set 13 | port blair
# Processing Record 4 of Set 13 | komsomolskiy
# Processing Record 5 of Set 13 | leiyang
# Processing Record 6 of Set 13 | tortoli
# Processing Record 7 of Set 13 | chumikan
# Processing Record 8 of Set 13 | jinka
# Processing Record 9 of Set 13 | tambul
# City not found. Skipping...
# Processing Record 10 of Set 13 | wheatley
# Processing Record 11 of Set 13 | maraa
# Processing Record 12 of Set 13 | liepaja
# Processing Record 13 of Set 13 | kimbe
# Processing Record 14 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 13 | hibbing
# Processing Record 16 of Set 13 | morro bay
# Processing Record 17 of Set 13 | khudumelapye
# Processing Record 18 of Set 13 | thunder bay
# Processing Record 19 of Set 13 | merritt
# Processing Record 20 of Set 13 | sidi ali
# Processing Record 21 of Set 13 | portree
# Processing Record 22 of Set 13 | liberal
# Processing Record 23 of Set 13 | lerwick
# Processing Record 24 of Set 13 | huangyan
# Processing Record 25 of Set 13 | flinders
# Processing Record 26 of Set 13 | shache
# Processing Record 27 of Set 13 | semey
# Processing Record 28 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 29 of Set 13 | salta
# Processing Record 30 of Set 13 | mariental
# Processing Record 31 of Set 13 | tambopata
# Processing Record 32 of Set 13 | sim
# Processing Record 33 of Set 13 | estelle
# Processing Record 34 of Set 13 | sarankhola
# Processing Record 35 of Set 13 | atambua
# Processing Record 36 of Set 13 | beringovskiy
# Processing Record 37 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 38 of Set 13 | bogorodskoye
# Processing Record 39 of Set 13 | cocobeach
# Processing Record 40 of Set 13 | yamada
# Processing Record 41 of Set 13 | uelzen
# Processing Record 42 of Set 13 | jalu
# Processing Record 43 of Set 13 | saldanha
# Processing Record 44 of Set 13 | langsa
# Processing Record 45 of Set 13 | buala
# Processing Record 46 of Set 13 | grand-santi
# Processing Record 47 of Set 13 | hillsborough
# Processing Record 48 of Set 13 | broken hill
# Processing Record 49 of Set 13 | nizhniy kuranakh
# Processing Record 50 of Set 13 | shelburne
# Processing Record 1 of Set 14 | hobyo
# Processing Record 2 of Set 14 | bria
# Processing Record 3 of Set 14 | rozivka
# Processing Record 4 of Set 14 | cape coast
# Processing Record 5 of Set 14 | kose-uuemoisa
# City not found. Skipping...
# Processing Record 6 of Set 14 | abu dhabi
# Processing Record 7 of Set 14 | palmer
# Processing Record 8 of Set 14 | slave lake
# Processing Record 9 of Set 14 | rabat
# Processing Record 10 of Set 14 | luderitz
# Processing Record 11 of Set 14 | matara
# Processing Record 12 of Set 14 | roma
# Processing Record 13 of Set 14 | kutum
# Processing Record 14 of Set 14 | damietta
# Processing Record 15 of Set 14 | acapulco
# Processing Record 16 of Set 14 | pauini
# Processing Record 17 of Set 14 | mayor pablo lagerenza
# Processing Record 18 of Set 14 | yatou
# Processing Record 19 of Set 14 | pangkalanbuun
# Processing Record 20 of Set 14 | brownsville
# Processing Record 21 of Set 14 | praya
# Processing Record 22 of Set 14 | kofele
# Processing Record 23 of Set 14 | bubaque
# Processing Record 24 of Set 14 | noumea
# Processing Record 25 of Set 14 | simao
# Processing Record 26 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 27 of Set 14 | shentala
# Processing Record 28 of Set 14 | dalvik
# Processing Record 29 of Set 14 | rock sound
# Processing Record 30 of Set 14 | vung tau
# Processing Record 31 of Set 14 | calama
# Processing Record 32 of Set 14 | dorado
# Processing Record 33 of Set 14 | yangambi
# Processing Record 34 of Set 14 | xapuri
# Processing Record 35 of Set 14 | minsk
# Processing Record 36 of Set 14 | gasa
# Processing Record 37 of Set 14 | mayumba
# Processing Record 38 of Set 14 | bairiki
# Processing Record 39 of Set 14 | honiara
# Processing Record 40 of Set 14 | pontes e lacerda
# Processing Record 41 of Set 14 | campbell river
# Processing Record 42 of Set 14 | paka
# Processing Record 43 of Set 14 | fallon
# Processing Record 44 of Set 14 | isangel
# Processing Record 45 of Set 14 | stephenville
# Processing Record 46 of Set 14 | champaign
# Processing Record 47 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 14 | bonthe
# Processing Record 49 of Set 14 | tingi
# Processing Record 50 of Set 14 | rundu
# Processing Record 1 of Set 15 | havoysund
# Processing Record 2 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 3 of Set 15 | khasan
# Processing Record 4 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 15 | namatanai
# Processing Record 6 of Set 15 | xining
# Processing Record 7 of Set 15 | weihai
# Processing Record 8 of Set 15 | talnakh
# Processing Record 9 of Set 15 | laredo
# Processing Record 10 of Set 15 | mananjary
# Processing Record 11 of Set 15 | shingu
# Processing Record 12 of Set 15 | barcelona
# Processing Record 13 of Set 15 | nichinan
# Processing Record 14 of Set 15 | san policarpo
# Processing Record 15 of Set 15 | brookings
# Processing Record 16 of Set 15 | finote selam
# Processing Record 17 of Set 15 | puerto escondido
# Processing Record 18 of Set 15 | oakdale
# Processing Record 19 of Set 15 | kangaatsiaq
# Processing Record 20 of Set 15 | kilindoni
# Processing Record 21 of Set 15 | mogoytuy
# Processing Record 22 of Set 15 | clarence town
# Processing Record 23 of Set 15 | shaoyang
# Processing Record 24 of Set 15 | pundaguitan
# Processing Record 25 of Set 15 | oktyabrskiy
# Processing Record 26 of Set 15 | truth or consequences
# Processing Record 27 of Set 15 | marawi
# Processing Record 28 of Set 15 | borogontsy
# Processing Record 29 of Set 15 | edd
# Processing Record 30 of Set 15 | tibagi
# Processing Record 31 of Set 15 | kukuna
# Processing Record 32 of Set 15 | macon
# Processing Record 33 of Set 15 | aleysk
# Processing Record 34 of Set 15 | dunedin
# Processing Record 35 of Set 15 | zhigansk
# Processing Record 36 of Set 15 | sobolevo
# Processing Record 37 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 15 | songjianghe
# Processing Record 39 of Set 15 | lalomanu
# City not found. Skipping...
# Processing Record 40 of Set 15 | paamiut
# Processing Record 41 of Set 15 | ordzhonikidze
# Processing Record 42 of Set 15 | vysokogornyy
# Processing Record 43 of Set 15 | cartagena
# Processing Record 44 of Set 15 | itaituba
# Processing Record 45 of Set 15 | rio gallegos
# Processing Record 46 of Set 15 | valparaiso
# Processing Record 47 of Set 15 | aklavik
# Processing Record 48 of Set 15 | dubai
# Processing Record 49 of Set 15 | goleta
# Processing Record 50 of Set 15 | wanaka
# Processing Record 1 of Set 16 | tawkar
# City not found. Skipping...
# Processing Record 2 of Set 16 | emba
# Processing Record 3 of Set 16 | kobryn
# Processing Record 4 of Set 16 | cam ranh
# Processing Record 5 of Set 16 | singaparna
# Processing Record 6 of Set 16 | macas
# Processing Record 7 of Set 16 | xinzhou
# Processing Record 8 of Set 16 | tuggurt
# City not found. Skipping...
# Processing Record 9 of Set 16 | the valley
# Processing Record 10 of Set 16 | mount pleasant
# Processing Record 11 of Set 16 | petapa
# Processing Record 12 of Set 16 | kosiv
# Processing Record 13 of Set 16 | north bend
# Processing Record 14 of Set 16 | katobu
# Processing Record 15 of Set 16 | carutapera
# Processing Record 16 of Set 16 | kichmengskiy gorodok
# Processing Record 17 of Set 16 | kampene
# Processing Record 18 of Set 16 | tual
# Processing Record 19 of Set 16 | mundo nuevo
# Processing Record 20 of Set 16 | kontagora
# Processing Record 21 of Set 16 | ponta delgada
# Processing Record 22 of Set 16 | biak
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Majene      ID  -3.5403  118.9707     79.88        84         100
# 1            Bluff      NZ -46.6000  168.3333     46.80        83         100
# 2          Ushuaia      AR -54.8000  -68.3000     37.06        75           0
# 3        Jamestown      US  42.0970  -79.2353     69.51        75           0
# 4            Kapaa      US  22.0752 -159.3190     77.32        85          20
# ..             ...     ...      ...       ...       ...       ...         ...
# 699           Tual      ID  -5.6667  132.7500     81.75        77         100
# 700    Mundo Nuevo      MX  18.7000  -95.5000     76.30        93         100
# 701      Kontagora      NG  10.3999    5.4695     82.44        69          46
# 702  Ponta Delgada      PT  37.7333  -25.6667     77.72        73          20
# 703           Biak      ID  -0.9131  122.8766     77.23        83         100
#
#      Wind Speed Current Description
# 0          1.54     overcast clouds
# 1          8.48     overcast clouds
# 2          8.05           clear sky
# 3          6.91           clear sky
# 4         10.36          few clouds
# ..          ...                 ...
# 699       13.18     overcast clouds
# 700        7.52     overcast clouds
# 701        3.02          light rain
# 702        8.05          few clouds
# 703        3.29     overcast clouds
#
# [704 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
